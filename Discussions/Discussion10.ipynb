# %% [markdown]
# # Discussion Week 12
#
# In this discussion we will explore Markov Chains.
#
# You can use the Shared Computing Cluster (SCC) or Google Colab to run this notebook.
#
# The general instructions for running on the SCC are available under General Resources on [Piazza](https://piazza.com/bu/fall2025/ds722/resources).

# %% [markdown]
# ## Powers of a Matrix $A^{k}$
#
# Given the following matrix
#
# $$
# A =
# \begin{bmatrix}
# 0.5 & 0.2 & 0.1 \\
# 0.1 & 0.4 & 0.2 \\
# 0.2 & 0.1 & 0.3 \\
# \end{bmatrix},
# $$
#
# compute $A^{k}$ when $k=5, 10, 20, 50, 100$. What is the limit of this process as $k\rightarrow\infty$?
#
# Using NumPy compute the absolute value of the eigenvalues of $A$.
#
# Determine what condition must be true for $A^{k}\rightarrow 0$ as $k\rightarrow\infty$?

# %%
# TODO
import numpy as np

# %% [markdown]
# If $\vert \lambda\vert<1$ for all eigenvalues of $A$, then $A^{k}\rightarrow 0$ as $k\rightarrow\infty$.

# %% [markdown]
# ## Markov Chain
#
#  We classify the women in a country according to whether they live in an urban (U), suburban (S), or rural (R) area.
# Each woman has just one daughter, who also has just one daughter, and so on.<br>
# Suppose further that the following is true:<br>
#
# - For urban women, 10% of the daughters settle in rural areas, and 50% in suburban areas. The remaining 40% stay in urban areas.
# - For suburban women, 20% of the daughters settle in rural areas, and 30% in urban areas. The remaining 50% stay in suburban areas.
# - For rural women, 20% of the daughters settle in the suburbs, and 70% in rural areas. The remaining 10% move to urban areas.
#
# Using NumPy, answer the following questions:
#
# 1. Give the transition matrix $P$ for this Markov chain, taking states in the order U, S, R.
# 1. Find the proportion of urban women whose granddaughters are suburban women.
# 1. Find the proportion of rural women whose granddaughters are rural women.
# 1. If the initial population distribution vector for all the women is $\begin{bmatrix} 0.4 \\ 0.5 \\ 0.1 \end{bmatrix}$, find the population distribution for the next generation.
# 1. Compute the eigenvalues and eigenvectors of the transition matrix $P$. What is the steady state distribution of the Markov chain?
#
# ```python

# %%
# TODO
